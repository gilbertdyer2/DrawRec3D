# %%
from tensorflow.keras.models import load_model
import os

# %load_ext autoreload 
# %autoreload 2

import tensorflow as tf
from tensorflow.keras import layers, models


# From model script, workaround to serialize embed layer
@tf.keras.utils.register_keras_serializable()
class L2Normalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(L2Normalization, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.math.l2_normalize(inputs, axis=1)

    def get_config(self):
        config = super(L2Normalization, self).get_config()
        return config


# Load the trained encoder
# encoder = load_model("../drawing_encoder_model.h5")
encoder = tf.keras.models.load_model(
    "../drawing_encoder_model.h5",
    custom_objects={'L2Normalization': L2Normalization}
)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from scipy.spatial.distance import cdist
from raw_to_dataset import sample_points_fixed, load_drawing_xyz

# Computes the distance matrix for a list of points

def compute_distance_matrix(points):
    """
    points: (num_points, 3)
    returns: (num_points, num_points) distance matrix
    """
    points = np.asarray(points, dtype=np.float32)

    diff = points[:, None, :] - points[None, :, :]
    dist = np.linalg.norm(diff, axis=-1)

    scale = np.max(dist)
    return dist / (scale + 1e-8)


def compute_distance_matrix_heightchannel(points):
    """
    points: (num_points, 3)
    returns: (num_points, num_points, 2) -> [Distance, Y-Diff]
    """
    points = np.asarray(points, dtype=np.float32)

    # Channel 1: Euclidean Distance (The Shape)
    diff = points[:, None, :] - points[None, :, :]
    dist = np.linalg.norm(diff, axis=-1)
    
    # Global scale for normalization (applied to both channels to keep aspect ratio)
    scale = np.max(dist) + 1e-8
    dist_norm = dist / scale

    # Channel 2: Y-Axis Difference (The Orientation / Up-ness)
    # Calculates (y1 - y2) for every point pair
    y_diff = points[:, 1][:, None] - points[None, :, 1]
    y_diff_norm = y_diff / scale

    # Stack them: Result is (128, 128, 2)
    return np.stack([dist_norm, y_diff_norm], axis=-1)


# Gets an embedding for a drawing (represented by a list of xyz points)
def get_embedding(drawing_points):
    """
    drawing_points: (128, 3) numpy array of a drawing
    returns: (EMBED_DIM,) embedding
    """
    dist_matrix = compute_distance_matrix_heightchannel(drawing_points)
    dist_matrix = np.expand_dims(dist_matrix, axis=0)  # batch dimension
    embedding = encoder.predict(dist_matrix, verbose=0)
    return embedding[0]



# Gets a comparison score between 2 drawings
def compare_drawings(drawing1, drawing2):
    """
    drawing1: (128, 3) numpy array of a drawing
    drawing2: (128, 3) numpy array of a drawing
    """
    emb1 = get_embedding(drawing1)
    emb2 = get_embedding(drawing2)

    score = np.linalg.norm(emb1 - emb2)
    return score

# Gets comparison score between 2 drawings, given filepaths to .json representations
def compare_drawings_filepath(filepath1, filepath2):
    """
    filepath1, filepath2: string filepaths to .json format of drawings, can be of any size. See sample data.
    """
    points1 = load_drawing_xyz(filepath1)
    points2 = load_drawing_xyz(filepath2)
    return compare_drawings(points1, points2)

# %%
# Compare to all .json drawings in sample_data, 
#  - allows multiple representations of each drawing and takes the average score
base_dir = "../dataset_RAW/validation"

# Returns the name of the closest drawing folder to a specified .json file
def get_closest_class_folder(filename, list_top_N=5):
    lowest_score = float('inf') # lower = closer match
    match = "NOT FOUND, CHECK base_dir OR FOLDER LAYOUT"
    chosen_file = "NONE"
    scores = []

    for folder in os.listdir(base_dir):
        folder_path = os.path.join(base_dir, folder)
        if not os.path.isdir(folder_path):
            continue
        
        for file_to_compare in os.listdir(folder_path):
            # Skip same file or invalid
            comparison_drawing_path = os.path.join(folder_path, file_to_compare)

            if comparison_drawing_path == filename or not file_to_compare.endswith(".json"):
                continue

            dist = compare_drawings_filepath(filename, comparison_drawing_path)
            if (dist < lowest_score):
                lowest_score = dist
                match = folder
                chosen_file = file_to_compare

            scores.append((dist, file_to_compare))

    scores.sort()
    print(f"\t\tGot top 5: {scores[0:5]}")
    return match, chosen_file
          
num_correct = 0
num_drawings = 0
drawing_scores = {} # dict to view accuracy for each drawing

# Get accuracy of comparison between every drawing class' examples, using the validation dataset as representations for each class
for folder in os.listdir(base_dir):
    print(f"Comparing {folder}...")
    folder_path = os.path.join(base_dir, folder)

    if not os.path.isdir(folder_path):
        continue
    
    num_correct_here = 0
    # Get score of each drawing
    for i, filename in enumerate(os.listdir(folder_path)):
        if not filename.endswith(".json"):
            continue
        print(f"\tFinding match to {filename}...")

        drawing_path = os.path.join(folder_path, filename)
        
        match, chosen_file = get_closest_class_folder(drawing_path)

        if (match == folder):
            num_correct_here += 1
            print(f"\t\tCorrect match to {filename} [Score: {num_correct_here}/{i + 1}] (chose {chosen_file})")
        else:
            print(f"\t\tIncorrect match to {filename} [Score: {num_correct_here}/{i + 1}] (chose {chosen_file})")

    num_drawings_here = len(os.listdir(folder_path))
    drawing_scores[folder] = f"{num_correct_here}/{num_drawings_here}"

    num_correct += num_correct_here
    num_drawings += num_drawings_here

# Print results for each drawing
for folder, score in drawing_scores.items():
    if folder is None:
        print(f"{folder}: (no drawings found)")
    else:
        print(f"{folder}: {score}")

print(f"Completed Validation. Overall Score: {num_correct / num_drawings} ({num_correct}/{num_drawings})")
# Out:
# Comparing cube...
# 	Finding match to cube_20251231_170814_696.json...
# 		Got top 5: [(0.26297984, 'cube_20251231_171503_880.json'), (0.3632137, 'cube_20251231_170949_256.json'), (0.3803306, 'triPrism_vertical_20260101_135552_977.json'), (0.42378822, 'cube_20251231_171225_854.json'), (0.4475908, 'triPrism_vertical_20260101_135503_462.json')]
# 		Correct match to cube_20251231_170814_696.json [Score: 1/1] (chose cube_20251231_171503_880.json)
# 	Finding match to cube_20251231_170949_256.json...
# 		Got top 5: [(0.10817425, 'cube_20251231_171225_854.json'), (0.22735706, 'rectangle_horizontal_20251231_172850_073.json'), (0.2340456, 'cube_20251231_171503_880.json'), (0.3632137, 'cube_20251231_170814_696.json'), (0.37512967, 'rectangle_horizontal_20251231_173231_647.json')]
# 		Correct match to cube_20251231_170949_256.json [Score: 2/2] (chose cube_20251231_171225_854.json)
# 	Finding match to cube_20251231_171225_854.json...
# 		Got top 5: [(0.10817425, 'cube_20251231_170949_256.json'), (0.2258948, 'cube_20251231_171503_880.json'), (0.29462993, 'rectangle_horizontal_20251231_172850_073.json'), (0.34495696, 'rectangleTriPrismOnSide_20260104_192623_712.json'), (0.35881796, 'rectangleTriPrismOnSide_20260104_192105_214.json')]
# 		Correct match to cube_20251231_171225_854.json [Score: 3/3] (chose cube_20251231_170949_256.json)
# 	Finding match to cube_20251231_171503_880.json...
# 		Got top 5: [(0.2258948, 'cube_20251231_171225_854.json'), (0.2340456, 'cube_20251231_170949_256.json'), (0.26297984, 'cube_20251231_170814_696.json'), (0.45562208, 'rectangle_horizontal_20251231_172850_073.json'), (0.50257313, 'rectangleTriPrismOnSide_20260104_192623_712.json')]
# 		Correct match to cube_20251231_171503_880.json [Score: 4/4] (chose cube_20251231_171225_854.json)
# Comparing cubeThinCylinderStack...
# 	Finding match to cubeThinCylinderStack_20260104_214215_200.json...
# 		Got top 5: [(0.0008141407, 'cubeThinCylinderStack_20260104_215117_346.json'), (0.005672492, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.0073167696, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.012101305, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.021651523, 'tripleRectangleStackNarrowing_20260104_213312_074.json')]
# 		Correct match to cubeThinCylinderStack_20260104_214215_200.json [Score: 1/1] (chose cubeThinCylinderStack_20260104_215117_346.json)
# 	Finding match to cubeThinCylinderStack_20260104_214316_970.json...
# 		Got top 5: [(0.0073167696, 'cubeThinCylinderStack_20260104_214215_200.json'), (0.007987011, 'cubeThinCylinderStack_20260104_215117_346.json'), (0.011468759, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.0115048485, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.021741629, 'tripleRectangleStackNarrowing_20260104_213312_074.json')]
# 		Correct match to cubeThinCylinderStack_20260104_214316_970.json [Score: 2/2] (chose cubeThinCylinderStack_20260104_214215_200.json)
# 	Finding match to cubeThinCylinderStack_20260104_214751_480.json...
# 		Got top 5: [(0.011468759, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.011967879, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.012101305, 'cubeThinCylinderStack_20260104_214215_200.json'), (0.012675, 'cubeThinCylinderStack_20260104_215117_346.json'), (0.03194022, 'tripleRectangleStackNarrowing_20260104_213312_074.json')]
# 		Correct match to cubeThinCylinderStack_20260104_214751_480.json [Score: 3/3] (chose cubeThinCylinderStack_20260104_214316_970.json)
# 	Finding match to cubeThinCylinderStack_20260104_215117_346.json...
# 		Got top 5: [(0.0008141407, 'cubeThinCylinderStack_20260104_214215_200.json'), (0.005342198, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.007987011, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.012675, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.021424204, 'tripleRectangleStackNarrowing_20260104_213312_074.json')]
# 		Correct match to cubeThinCylinderStack_20260104_215117_346.json [Score: 4/4] (chose cubeThinCylinderStack_20260104_214215_200.json)
# Comparing cubeTriPrismStack_house...
# 	Finding match to cubeTriPrismStack_house_20260104_192806_537.json...
# 		Got top 5: [(0.04476764, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.04909098, 'LBox_vertical_20260101_140701_847.json'), (0.052131824, 'cubeTriPrismStack_house_20260104_192904_654.json'), (0.06532869, 'LBox_vertical_20260101_140502_085.json'), (0.105653785, 'LBox_vertical_20260101_140905_886.json')]
# 		Correct match to cubeTriPrismStack_house_20260104_192806_537.json [Score: 1/1] (chose cubeTriPrismStack_house_20260104_193202_468.json)
# 	Finding match to cubeTriPrismStack_house_20260104_192904_654.json...
# 		Got top 5: [(0.022160472, 'LBox_vertical_20260101_140502_085.json'), (0.031020429, 'LBox_vertical_20260101_140701_847.json'), (0.0451224, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.052131824, 'cubeTriPrismStack_house_20260104_192806_537.json'), (0.15423816, 'LBox_vertical_20260101_140905_886.json')]
# 		Incorrect match to cubeTriPrismStack_house_20260104_192904_654.json [Score: 1/2] (chose LBox_vertical_20260101_140502_085.json)
# 	Finding match to cubeTriPrismStack_house_20260104_192926_322.json...
# 		Got top 5: [(0.12809676, 'rectangleTriPrismOnSide_20260104_191832_369.json'), (0.14214703, 'LBox_vertical_20260101_140728_137.json'), (0.15839048, 'rectangleTriPrismOnSide_20260104_191927_273.json'), (0.18552978, 'LBox_vertical_20260101_140905_886.json'), (0.22251828, 'cubeTriPrismStack_house_20260104_192806_537.json')]
# 		Incorrect match to cubeTriPrismStack_house_20260104_192926_322.json [Score: 1/3] (chose rectangleTriPrismOnSide_20260104_191832_369.json)
# 	Finding match to cubeTriPrismStack_house_20260104_193202_468.json...
# 		Got top 5: [(0.018615678, 'LBox_vertical_20260101_140701_847.json'), (0.04476764, 'cubeTriPrismStack_house_20260104_192806_537.json'), (0.0451224, 'cubeTriPrismStack_house_20260104_192904_654.json'), (0.061804924, 'LBox_vertical_20260101_140502_085.json'), (0.14538772, 'LBox_vertical_20260101_140905_886.json')]
# 		Incorrect match to cubeTriPrismStack_house_20260104_193202_468.json [Score: 1/4] (chose LBox_vertical_20260101_140701_847.json)
# Comparing cylinder...
# 	Finding match to cylinder_20260101_134352_404.json...
# 		Got top 5: [(0.012266394, 'cylinder_20260101_134539_568.json'), (0.02209401, 'cylinder_20260101_134646_264.json'), (0.1267417, 'cylinder_20260101_134424_468.json'), (0.19413675, 'rectangle_vertical_20251231_172523_474.json'), (0.20517507, 'triPrism_vertical_20260101_135346_452.json')]
# 		Correct match to cylinder_20260101_134352_404.json [Score: 1/1] (chose cylinder_20260101_134539_568.json)
# 	Finding match to cylinder_20260101_134424_468.json...
# 		Got top 5: [(0.032755826, 'triPrism_vertical_20260101_135306_826.json'), (0.099928886, 'rectangle_vertical_20251231_172523_474.json'), (0.1148694, 'cylinder_20260101_134539_568.json'), (0.1267417, 'cylinder_20260101_134352_404.json'), (0.13937293, 'cylinder_20260101_134646_264.json')]
# 		Incorrect match to cylinder_20260101_134424_468.json [Score: 1/2] (chose triPrism_vertical_20260101_135306_826.json)
# 	Finding match to cylinder_20260101_134539_568.json...
# 		Got top 5: [(0.012266394, 'cylinder_20260101_134352_404.json'), (0.029922199, 'cylinder_20260101_134646_264.json'), (0.10467013, 'triPrism_vertical_20260101_135306_826.json'), (0.10833496, 'triPrism_vertical_20260101_135346_452.json'), (0.1148694, 'cylinder_20260101_134424_468.json')]
# 		Correct match to cylinder_20260101_134539_568.json [Score: 2/3] (chose cylinder_20260101_134352_404.json)
# 	Finding match to cylinder_20260101_134646_264.json...
# 		Got top 5: [(0.02209401, 'cylinder_20260101_134352_404.json'), (0.029922199, 'cylinder_20260101_134539_568.json'), (0.1268252, 'triPrism_vertical_20260101_135503_462.json'), (0.13937293, 'cylinder_20260101_134424_468.json'), (0.21300612, 'rectangle_vertical_20251231_172523_474.json')]
# 		Correct match to cylinder_20260101_134646_264.json [Score: 3/4] (chose cylinder_20260101_134352_404.json)
# Comparing flatRectangle...
# 	Finding match to flatRectangle_20251231_173545_762.json...
# 		Got top 5: [(0.021022577, 'flatRectangle_20251231_173941_923.json'), (0.030066432, 'flatRectangle_20251231_173738_979.json'), (0.049783736, 'flatRectangle_20251231_173643_673.json'), (0.14805096, 'oval_concertHall_20260101_133655_944.json'), (0.23373738, 'oval_concertHall_20260101_134040_106.json')]
# 		Correct match to flatRectangle_20251231_173545_762.json [Score: 1/1] (chose flatRectangle_20251231_173941_923.json)
# 	Finding match to flatRectangle_20251231_173643_673.json...
# 		Got top 5: [(0.02922613, 'flatRectangle_20251231_173941_923.json'), (0.049783736, 'flatRectangle_20251231_173545_762.json'), (0.07975755, 'flatRectangle_20251231_173738_979.json'), (0.09963981, 'oval_concertHall_20260101_133655_944.json'), (0.15261117, 'oval_concertHall_20260101_133800_223.json')]
# 		Correct match to flatRectangle_20251231_173643_673.json [Score: 2/2] (chose flatRectangle_20251231_173941_923.json)
# 	Finding match to flatRectangle_20251231_173738_979.json...
# 		Got top 5: [(0.030066432, 'flatRectangle_20251231_173545_762.json'), (0.05101641, 'flatRectangle_20251231_173941_923.json'), (0.07975755, 'flatRectangle_20251231_173643_673.json'), (0.14140698, 'oval_concertHall_20260101_134040_106.json'), (0.17785904, 'oval_concertHall_20260101_133655_944.json')]
# 		Correct match to flatRectangle_20251231_173738_979.json [Score: 3/3] (chose flatRectangle_20251231_173545_762.json)
# 	Finding match to flatRectangle_20251231_173941_923.json...
# 		Got top 5: [(0.021022577, 'flatRectangle_20251231_173545_762.json'), (0.02922613, 'flatRectangle_20251231_173643_673.json'), (0.05101641, 'flatRectangle_20251231_173738_979.json'), (0.12714462, 'oval_concertHall_20260101_133655_944.json'), (0.1681639, 'oval_concertHall_20260101_134040_106.json')]
# 		Correct match to flatRectangle_20251231_173941_923.json [Score: 4/4] (chose flatRectangle_20251231_173545_762.json)
# Comparing LBoxTriRoof...
# 	Finding match to LBoxTriRoof_20260104_185801_133.json...
# 		Got top 5: [(0.05839217, 'rectangle_horizontal_20251231_172908_423.json'), (0.13910149, 'oval_concertHall_20260101_133800_223.json'), (0.1512469, 'oval_concertHall_20260101_133901_569.json'), (0.15848349, 'oval_concertHall_20260101_134040_106.json'), (0.16732876, 'oval_concertHall_20260101_133655_944.json')]
# 		Incorrect match to LBoxTriRoof_20260104_185801_133.json [Score: 0/1] (chose rectangle_horizontal_20251231_172908_423.json)
# 	Finding match to LBoxTriRoof_20260104_185924_944.json...
# 		Got top 5: [(0.022951618, 'LBoxTriRoof_20260104_190555_378.json'), (0.081887156, 'rectangle_horizontal_20251231_172949_923.json'), (0.08454492, 'oval_concertHall_20260101_133901_569.json'), (0.089195244, 'LBoxTriRoof_20260104_191225_638.json'), (0.10628565, 'rectangle_horizontal_20251231_173231_647.json')]
# 		Correct match to LBoxTriRoof_20260104_185924_944.json [Score: 1/2] (chose LBoxTriRoof_20260104_190555_378.json)
# 	Finding match to LBoxTriRoof_20260104_190555_378.json...
# 		Got top 5: [(0.022951618, 'LBoxTriRoof_20260104_185924_944.json'), (0.069641866, 'rectangle_horizontal_20251231_172949_923.json'), (0.08678017, 'rectangle_horizontal_20251231_173231_647.json'), (0.093731835, 'oval_concertHall_20260101_133901_569.json'), (0.0996183, 'LBoxTriRoof_20260104_191225_638.json')]
# 		Correct match to LBoxTriRoof_20260104_190555_378.json [Score: 2/3] (chose LBoxTriRoof_20260104_185924_944.json)
# 	Finding match to LBoxTriRoof_20260104_191225_638.json...
# 		Got top 5: [(0.089195244, 'LBoxTriRoof_20260104_185924_944.json'), (0.0996183, 'LBoxTriRoof_20260104_190555_378.json'), (0.13114527, 'rectangle_horizontal_20251231_173231_647.json'), (0.16041344, 'oval_concertHall_20260101_133901_569.json'), (0.16672467, 'rectangle_horizontal_20251231_172949_923.json')]
# 		Correct match to LBoxTriRoof_20260104_191225_638.json [Score: 3/4] (chose LBoxTriRoof_20260104_185924_944.json)
# Comparing LBox_vertical...
# 	Finding match to LBox_vertical_20260101_140502_085.json...
# 		Got top 5: [(0.022160472, 'cubeTriPrismStack_house_20260104_192904_654.json'), (0.045526452, 'LBox_vertical_20260101_140701_847.json'), (0.061804924, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.06532869, 'cubeTriPrismStack_house_20260104_192806_537.json'), (0.16247809, 'LBox_vertical_20260101_140905_886.json')]
# 		Incorrect match to LBox_vertical_20260101_140502_085.json [Score: 0/1] (chose cubeTriPrismStack_house_20260104_192904_654.json)
# 	Finding match to LBox_vertical_20260101_140701_847.json...
# 		Got top 5: [(0.018615678, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.031020429, 'cubeTriPrismStack_house_20260104_192904_654.json'), (0.045526452, 'LBox_vertical_20260101_140502_085.json'), (0.04909098, 'cubeTriPrismStack_house_20260104_192806_537.json'), (0.15325676, 'LBox_vertical_20260101_140905_886.json')]
# 		Incorrect match to LBox_vertical_20260101_140701_847.json [Score: 0/2] (chose cubeTriPrismStack_house_20260104_193202_468.json)
# 	Finding match to LBox_vertical_20260101_140728_137.json...
# 		Got top 5: [(0.03820361, 'rectangleTriPrismOnSide_20260104_191927_273.json'), (0.11916673, 'rectangleTriPrismOnSide_20260104_191832_369.json'), (0.14214703, 'cubeTriPrismStack_house_20260104_192926_322.json'), (0.29722401, 'rectangleTriPrismOnSide_20260104_192105_214.json'), (0.31423682, 'rectangleTriPrismOnSide_20260104_192623_712.json')]
# 		Incorrect match to LBox_vertical_20260101_140728_137.json [Score: 0/3] (chose rectangleTriPrismOnSide_20260104_191927_273.json)
# 	Finding match to LBox_vertical_20260101_140905_886.json...
# 		Got top 5: [(0.105653785, 'cubeTriPrismStack_house_20260104_192806_537.json'), (0.14538772, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.15325676, 'LBox_vertical_20260101_140701_847.json'), (0.15423816, 'cubeTriPrismStack_house_20260104_192904_654.json'), (0.16247809, 'LBox_vertical_20260101_140502_085.json')]
# 		Incorrect match to LBox_vertical_20260101_140905_886.json [Score: 0/4] (chose cubeTriPrismStack_house_20260104_192806_537.json)
# Comparing oval_concertHall...
# 	Finding match to oval_concertHall_20260101_133655_944.json...
# 		Got top 5: [(0.028943257, 'oval_concertHall_20260101_134040_106.json'), (0.09963981, 'flatRectangle_20251231_173643_673.json'), (0.12714462, 'flatRectangle_20251231_173941_923.json'), (0.14805096, 'flatRectangle_20251231_173545_762.json'), (0.16732876, 'LBoxTriRoof_20260104_185801_133.json')]
# 		Correct match to oval_concertHall_20260101_133655_944.json [Score: 1/1] (chose oval_concertHall_20260101_134040_106.json)
# 	Finding match to oval_concertHall_20260101_133800_223.json...
# 		Got top 5: [(0.05421483, 'oval_concertHall_20260101_134040_106.json'), (0.059679378, 'oval_concertHall_20260101_133655_944.json'), (0.071578175, 'flatRectangle_20251231_173941_923.json'), (0.14345649, 'rectangle_horizontal_20251231_172908_423.json'), (0.18151693, 'flatRectangle_20251231_173643_673.json')]
# 		Correct match to oval_concertHall_20260101_133800_223.json [Score: 2/2] (chose oval_concertHall_20260101_134040_106.json)
# 	Finding match to oval_concertHall_20260101_133901_569.json...
# 		Got top 5: [(0.0795384, 'rectangle_horizontal_20251231_172949_923.json'), (0.08454492, 'LBoxTriRoof_20260104_185924_944.json'), (0.093731835, 'LBoxTriRoof_20260104_190555_378.json'), (0.104666896, 'rectangle_horizontal_20251231_172908_423.json'), (0.1512469, 'LBoxTriRoof_20260104_185801_133.json')]
# 		Incorrect match to oval_concertHall_20260101_133901_569.json [Score: 2/3] (chose rectangle_horizontal_20251231_172949_923.json)
# 	Finding match to oval_concertHall_20260101_134040_106.json...
# 		Got top 5: [(0.023036037, 'flatRectangle_20251231_173643_673.json'), (0.030465437, 'oval_concertHall_20260101_133655_944.json'), (0.072568364, 'oval_concertHall_20260101_133800_223.json'), (0.12172476, 'LBoxTriRoof_20260104_185801_133.json'), (0.12668824, 'flatRectangle_20251231_173941_923.json')]
# 		Incorrect match to oval_concertHall_20260101_134040_106.json [Score: 2/4] (chose flatRectangle_20251231_173643_673.json)
# Comparing pyramid...
# 	Finding match to pyramid_20260101_133119_513.json...
# 		Got top 5: [(0.09631803, 'pyramid_20260101_133427_193.json'), (0.09760703, 'triPrism_horizontal_20260101_135653_173.json'), (0.11029648, 'pyramid_20260101_133209_240.json'), (0.12941799, 'pyramid_20260101_133317_760.json'), (0.19846286, 'triPrism_horizontal_20260101_140108_337.json')]
# 		Correct match to pyramid_20260101_133119_513.json [Score: 1/1] (chose pyramid_20260101_133427_193.json)
# 	Finding match to pyramid_20260101_133209_240.json...
# 		Got top 5: [(0.041732732, 'pyramid_20260101_133317_760.json'), (0.06643156, 'pyramid_20260101_133427_193.json'), (0.070690416, 'pyramid_20260101_133119_513.json'), (0.19767925, 'triPrism_horizontal_20260101_135653_173.json'), (0.26356766, 'triPrism_horizontal_20260101_140108_337.json')]
# 		Correct match to pyramid_20260101_133209_240.json [Score: 2/2] (chose pyramid_20260101_133317_760.json)
# 	Finding match to pyramid_20260101_133317_760.json...
# 		Got top 5: [(0.055106305, 'pyramid_20260101_133209_240.json'), (0.13596469, 'pyramid_20260101_133119_513.json'), (0.15708531, 'pyramid_20260101_133427_193.json'), (0.28420746, 'triPrism_horizontal_20260101_140108_337.json'), (0.28770033, 'triPrism_horizontal_20260101_135959_330.json')]
# 		Correct match to pyramid_20260101_133317_760.json [Score: 3/3] (chose pyramid_20260101_133209_240.json)
# 	Finding match to pyramid_20260101_133427_193.json...
# 		Got top 5: [(0.039376184, 'pyramid_20260101_133119_513.json'), (0.10884137, 'pyramid_20260101_133209_240.json'), (0.12935822, 'triPrism_horizontal_20260101_140108_337.json'), (0.13250716, 'pyramid_20260101_133317_760.json'), (0.13475044, 'triPrism_horizontal_20260101_135959_330.json')]
# 		Correct match to pyramid_20260101_133427_193.json [Score: 4/4] (chose pyramid_20260101_133119_513.json)
# Comparing rectangleTriPrismOnSide...
# 	Finding match to rectangleTriPrismOnSide_20260104_191832_369.json...
# 		Got top 5: [(0.10011007, 'rectangleTriPrismOnSide_20260104_191927_273.json'), (0.11916673, 'LBox_vertical_20260101_140728_137.json'), (0.12809676, 'cubeTriPrismStack_house_20260104_192926_322.json'), (0.2730699, 'cubeTriPrismStack_house_20260104_193202_468.json'), (0.2862706, 'cubeTriPrismStack_house_20260104_192806_537.json')]
# 		Correct match to rectangleTriPrismOnSide_20260104_191832_369.json [Score: 1/1] (chose rectangleTriPrismOnSide_20260104_191927_273.json)
# 	Finding match to rectangleTriPrismOnSide_20260104_191927_273.json...
# 		Got top 5: [(0.03820361, 'LBox_vertical_20260101_140728_137.json'), (0.10011007, 'rectangleTriPrismOnSide_20260104_191832_369.json'), (0.15839048, 'cubeTriPrismStack_house_20260104_192926_322.json'), (0.2873594, 'rectangleTriPrismOnSide_20260104_192105_214.json'), (0.3051463, 'rectangleTriPrismOnSide_20260104_192623_712.json')]
# 		Incorrect match to rectangleTriPrismOnSide_20260104_191927_273.json [Score: 1/2] (chose LBox_vertical_20260101_140728_137.json)
# 	Finding match to rectangleTriPrismOnSide_20260104_192105_214.json...
# 		Got top 5: [(0.019753465, 'rectangleTriPrismOnSide_20260104_192623_712.json'), (0.2873594, 'rectangleTriPrismOnSide_20260104_191927_273.json'), (0.29722401, 'LBox_vertical_20260101_140728_137.json'), (0.35881796, 'cube_20251231_171225_854.json'), (0.37343952, 'rectangleTriPrismOnSide_20260104_191832_369.json')]
# 		Correct match to rectangleTriPrismOnSide_20260104_192105_214.json [Score: 2/3] (chose rectangleTriPrismOnSide_20260104_192623_712.json)
# 	Finding match to rectangleTriPrismOnSide_20260104_192623_712.json...
# 		Got top 5: [(0.019753465, 'rectangleTriPrismOnSide_20260104_192105_214.json'), (0.3051463, 'rectangleTriPrismOnSide_20260104_191927_273.json'), (0.31423682, 'LBox_vertical_20260101_140728_137.json'), (0.34495696, 'cube_20251231_171225_854.json'), (0.39153123, 'rectangleTriPrismOnSide_20260104_191832_369.json')]
# 		Correct match to rectangleTriPrismOnSide_20260104_192623_712.json [Score: 3/4] (chose rectangleTriPrismOnSide_20260104_192105_214.json)
# Comparing rectangle_horizontal...
# 	Finding match to rectangle_horizontal_20251231_172850_073.json...
# 		Got top 5: [(0.15023074, 'rectangle_horizontal_20251231_173231_647.json'), (0.22735706, 'cube_20251231_170949_256.json'), (0.23648581, 'LBoxTriRoof_20260104_190555_378.json'), (0.2550917, 'LBoxTriRoof_20260104_191225_638.json'), (0.2553694, 'LBoxTriRoof_20260104_185924_944.json')]
# 		Correct match to rectangle_horizontal_20251231_172850_073.json [Score: 1/1] (chose rectangle_horizontal_20251231_173231_647.json)
# 	Finding match to rectangle_horizontal_20251231_172908_423.json...
# 		Got top 5: [(0.05839217, 'LBoxTriRoof_20260104_185801_133.json'), (0.07125194, 'oval_concertHall_20260101_134040_106.json'), (0.104666896, 'oval_concertHall_20260101_133901_569.json'), (0.1646566, 'oval_concertHall_20260101_133800_223.json'), (0.16917808, 'LBoxTriRoof_20260104_185924_944.json')]
# 		Incorrect match to rectangle_horizontal_20251231_172908_423.json [Score: 1/2] (chose LBoxTriRoof_20260104_185801_133.json)
# 	Finding match to rectangle_horizontal_20251231_172949_923.json...
# 		Got top 5: [(0.069641866, 'LBoxTriRoof_20260104_190555_378.json'), (0.0795384, 'oval_concertHall_20260101_133901_569.json'), (0.081887156, 'LBoxTriRoof_20260104_185924_944.json'), (0.11945971, 'rectangle_horizontal_20251231_173231_647.json'), (0.16672467, 'LBoxTriRoof_20260104_191225_638.json')]
# 		Incorrect match to rectangle_horizontal_20251231_172949_923.json [Score: 1/3] (chose LBoxTriRoof_20260104_190555_378.json)
# 	Finding match to rectangle_horizontal_20251231_173231_647.json...
# 		Got top 5: [(0.08678017, 'LBoxTriRoof_20260104_190555_378.json'), (0.10628565, 'LBoxTriRoof_20260104_185924_944.json'), (0.11945971, 'rectangle_horizontal_20251231_172949_923.json'), (0.13114527, 'LBoxTriRoof_20260104_191225_638.json'), (0.15023074, 'rectangle_horizontal_20251231_172850_073.json')]
# 		Incorrect match to rectangle_horizontal_20251231_173231_647.json [Score: 1/4] (chose LBoxTriRoof_20260104_190555_378.json)
# Comparing rectangle_vertical...
# 	Finding match to rectangle_vertical_20251231_171910_526.json...
# 		Got top 5: [(0.051542085, 'rectangle_vertical_20251231_172358_548.json'), (0.06460577, 'rectangle_vertical_20251231_172211_865.json'), (0.10152602, 'rectangle_vertical_20251231_172523_474.json'), (0.13511473, 'triPrism_vertical_20260101_135552_977.json'), (0.16707449, 'cylinder_20260101_134424_468.json')]
# 		Correct match to rectangle_vertical_20251231_171910_526.json [Score: 1/1] (chose rectangle_vertical_20251231_172358_548.json)
# 	Finding match to rectangle_vertical_20251231_172211_865.json...
# 		Got top 5: [(0.015579483, 'rectangle_vertical_20251231_172358_548.json'), (0.06460577, 'rectangle_vertical_20251231_171910_526.json'), (0.07046573, 'rectangle_vertical_20251231_172523_474.json'), (0.10840193, 'tallRectanglePyramidStack_20260104_220012_996.json'), (0.16434367, 'cylinder_20260101_134424_468.json')]
# 		Correct match to rectangle_vertical_20251231_172211_865.json [Score: 2/2] (chose rectangle_vertical_20251231_172358_548.json)
# 	Finding match to rectangle_vertical_20251231_172358_548.json...
# 		Got top 5: [(0.015579483, 'rectangle_vertical_20251231_172211_865.json'), (0.034186054, 'triPrism_vertical_20260101_135346_452.json'), (0.051542085, 'rectangle_vertical_20251231_171910_526.json'), (0.07909117, 'rectangle_vertical_20251231_172523_474.json'), (0.09087501, 'triPrism_vertical_20260101_135306_826.json')]
# 		Correct match to rectangle_vertical_20251231_172358_548.json [Score: 3/3] (chose rectangle_vertical_20251231_172211_865.json)
# 	Finding match to rectangle_vertical_20251231_172523_474.json...
# 		Got top 5: [(0.07046573, 'rectangle_vertical_20251231_172211_865.json'), (0.07909117, 'rectangle_vertical_20251231_172358_548.json'), (0.099928886, 'cylinder_20260101_134424_468.json'), (0.10152602, 'rectangle_vertical_20251231_171910_526.json'), (0.12702775, 'triPrism_vertical_20260101_135503_462.json')]
# 		Correct match to rectangle_vertical_20251231_172523_474.json [Score: 4/4] (chose rectangle_vertical_20251231_172211_865.json)
# Comparing tallRectanglePyramidStack...
# 	Finding match to tallRectanglePyramidStack_20260104_215539_995.json...
# 		Got top 5: [(0.15344289, 'tallRectanglePyramidStack_20260104_215639_487.json'), (0.41136113, 'tallRectanglePyramidStack_20260104_215942_118.json'), (0.44386932, 'triPrism_vertical_20260101_135346_452.json'), (0.594711, 'triPrism_vertical_20260101_135503_462.json'), (0.7090918, 'cylinder_20260101_134646_264.json')]
# 		Correct match to tallRectanglePyramidStack_20260104_215539_995.json [Score: 1/1] (chose tallRectanglePyramidStack_20260104_215639_487.json)
# 	Finding match to tallRectanglePyramidStack_20260104_215639_487.json...
# 		Got top 5: [(0.15344289, 'tallRectanglePyramidStack_20260104_215539_995.json'), (0.28440645, 'tallRectanglePyramidStack_20260104_215942_118.json'), (0.56998146, 'triPrism_vertical_20260101_135346_452.json'), (0.57034, 'cylinder_20260101_134646_264.json'), (0.58603024, 'cylinder_20260101_134352_404.json')]
# 		Correct match to tallRectanglePyramidStack_20260104_215639_487.json [Score: 2/2] (chose tallRectanglePyramidStack_20260104_215539_995.json)
# 	Finding match to tallRectanglePyramidStack_20260104_215942_118.json...
# 		Got top 5: [(0.28440645, 'tallRectanglePyramidStack_20260104_215639_487.json'), (0.30586, 'triPrism_vertical_20260101_135503_462.json'), (0.3263022, 'cylinder_20260101_134646_264.json'), (0.33736256, 'cylinder_20260101_134352_404.json'), (0.34848794, 'cylinder_20260101_134539_568.json')]
# 		Correct match to tallRectanglePyramidStack_20260104_215942_118.json [Score: 3/3] (chose tallRectanglePyramidStack_20260104_215639_487.json)
# 	Finding match to tallRectanglePyramidStack_20260104_220012_996.json...
# 		Got top 5: [(0.10840193, 'rectangle_vertical_20251231_172211_865.json'), (0.11951814, 'rectangle_vertical_20251231_172358_548.json'), (0.14351341, 'rectangle_vertical_20251231_172523_474.json'), (0.16751346, 'rectangle_vertical_20251231_171910_526.json'), (0.19747096, 'triPrism_vertical_20260101_135346_452.json')]
# 		Incorrect match to tallRectanglePyramidStack_20260104_220012_996.json [Score: 3/4] (chose rectangle_vertical_20251231_172211_865.json)
# Comparing tripleRectangleStackNarrowing...
# 	Finding match to tripleRectangleStackNarrowing_20260104_212341_420.json...
# 		Got top 5: [(0.005342198, 'cubeThinCylinderStack_20260104_215117_346.json'), (0.005672492, 'cubeThinCylinderStack_20260104_214215_200.json'), (0.0115048485, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.011967879, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.02557561, 'tripleRectangleStackNarrowing_20260104_213312_074.json')]
# 		Incorrect match to tripleRectangleStackNarrowing_20260104_212341_420.json [Score: 0/1] (chose cubeThinCylinderStack_20260104_215117_346.json)
# 	Finding match to tripleRectangleStackNarrowing_20260104_213007_332.json...
# 		Got top 5: [(0.0044654147, 'tripleRectangleStackNarrowing_20260104_213518_975.json'), (0.036569, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.045077365, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.046605263, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.04716341, 'cubeThinCylinderStack_20260104_214215_200.json')]
# 		Correct match to tripleRectangleStackNarrowing_20260104_213007_332.json [Score: 1/2] (chose tripleRectangleStackNarrowing_20260104_213518_975.json)
# 	Finding match to tripleRectangleStackNarrowing_20260104_213312_074.json...
# 		Got top 5: [(0.021424204, 'cubeThinCylinderStack_20260104_215117_346.json'), (0.021651523, 'cubeThinCylinderStack_20260104_214215_200.json'), (0.021741629, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.02557561, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.03194022, 'cubeThinCylinderStack_20260104_214751_480.json')]
# 		Incorrect match to tripleRectangleStackNarrowing_20260104_213312_074.json [Score: 1/3] (chose cubeThinCylinderStack_20260104_215117_346.json)
# 	Finding match to tripleRectangleStackNarrowing_20260104_213518_975.json...
# 		Got top 5: [(0.0044654147, 'tripleRectangleStackNarrowing_20260104_213007_332.json'), (0.032757398, 'cubeThinCylinderStack_20260104_214751_480.json'), (0.041408923, 'tripleRectangleStackNarrowing_20260104_212341_420.json'), (0.042718273, 'cubeThinCylinderStack_20260104_214316_970.json'), (0.043341637, 'cubeThinCylinderStack_20260104_214215_200.json')]
# 		Correct match to tripleRectangleStackNarrowing_20260104_213518_975.json [Score: 2/4] (chose tripleRectangleStackNarrowing_20260104_213007_332.json)
# Comparing triPrism_horizontal...
# 	Finding match to triPrism_horizontal_20260101_135653_173.json...
# 		Got top 5: [(0.16116694, 'triPrism_horizontal_20260101_135959_330.json'), (0.16657747, 'flatRectangle_20251231_173545_762.json'), (0.17675747, 'pyramid_20260101_133119_513.json'), (0.22411019, 'flatRectangle_20251231_173941_923.json'), (0.25012267, 'pyramid_20260101_133209_240.json')]
# 		Correct match to triPrism_horizontal_20260101_135653_173.json [Score: 1/1] (chose triPrism_horizontal_20260101_135959_330.json)
# 	Finding match to triPrism_horizontal_20260101_135830_452.json...
# 		Got top 5: [(0.12070602, 'triPrism_horizontal_20260101_140108_337.json'), (0.20810501, 'triPrism_horizontal_20260101_135959_330.json'), (0.27163523, 'flatRectangle_20251231_173545_762.json'), (0.28003162, 'pyramid_20260101_133119_513.json'), (0.2954014, 'flatRectangle_20251231_173643_673.json')]
# 		Correct match to triPrism_horizontal_20260101_135830_452.json [Score: 2/2] (chose triPrism_horizontal_20260101_140108_337.json)
# 	Finding match to triPrism_horizontal_20260101_135959_330.json...
# 		Got top 5: [(0.016469898, 'triPrism_horizontal_20260101_140108_337.json'), (0.10302289, 'pyramid_20260101_133427_193.json'), (0.14637133, 'triPrism_horizontal_20260101_135653_173.json'), (0.23783801, 'pyramid_20260101_133209_240.json'), (0.2570806, 'pyramid_20260101_133119_513.json')]
# 		Correct match to triPrism_horizontal_20260101_135959_330.json [Score: 3/3] (chose triPrism_horizontal_20260101_140108_337.json)
# 	Finding match to triPrism_horizontal_20260101_140108_337.json...
# 		Got top 5: [(0.03937473, 'triPrism_horizontal_20260101_135653_173.json'), (0.07735358, 'triPrism_horizontal_20260101_135959_330.json'), (0.07997295, 'triPrism_horizontal_20260101_135830_452.json'), (0.10236049, 'pyramid_20260101_133427_193.json'), (0.1827882, 'pyramid_20260101_133119_513.json')]
# 		Correct match to triPrism_horizontal_20260101_140108_337.json [Score: 4/4] (chose triPrism_horizontal_20260101_135653_173.json)
# Comparing triPrism_vertical...
# 	Finding match to triPrism_vertical_20260101_135306_826.json...
# 		Got top 5: [(0.08916937, 'rectangle_vertical_20251231_172523_474.json'), (0.10685883, 'triPrism_vertical_20260101_135346_452.json'), (0.108661674, 'rectangle_vertical_20251231_172211_865.json'), (0.15366314, 'cylinder_20260101_134424_468.json'), (0.25322053, 'tallRectanglePyramidStack_20260104_220012_996.json')]
# 		Incorrect match to triPrism_vertical_20260101_135306_826.json [Score: 0/1] (chose rectangle_vertical_20251231_172523_474.json)
# 	Finding match to triPrism_vertical_20260101_135346_452.json...
# 		Got top 5: [(0.030833261, 'cylinder_20260101_134539_568.json'), (0.03600368, 'rectangle_vertical_20251231_172523_474.json'), (0.07169524, 'triPrism_vertical_20260101_135552_977.json'), (0.16269323, 'cylinder_20260101_134424_468.json'), (0.17475656, 'cylinder_20260101_134646_264.json')]
# 		Incorrect match to triPrism_vertical_20260101_135346_452.json [Score: 0/2] (chose cylinder_20260101_134539_568.json)
# 	Finding match to triPrism_vertical_20260101_135503_462.json...
# 		Got top 5: [(0.024363013, 'rectangle_vertical_20251231_172211_865.json'), (0.060359556, 'cylinder_20260101_134539_568.json'), (0.068572894, 'triPrism_vertical_20260101_135552_977.json'), (0.1493996, 'cylinder_20260101_134352_404.json'), (0.15095061, 'rectangle_vertical_20251231_171910_526.json')]
# 		Incorrect match to triPrism_vertical_20260101_135503_462.json [Score: 0/3] (chose rectangle_vertical_20251231_172211_865.json)
# 	Finding match to triPrism_vertical_20260101_135552_977.json...
# 		Got top 5: [(0.13186024, 'cylinder_20260101_134539_568.json'), (0.1337136, 'cylinder_20260101_134646_264.json'), (0.16409765, 'rectangle_vertical_20251231_172523_474.json'), (0.1992938, 'cylinder_20260101_134424_468.json'), (0.25043434, 'rectangle_vertical_20251231_172358_548.json')]
# 		Incorrect match to triPrism_vertical_20260101_135552_977.json [Score: 0/4] (chose cylinder_20260101_134539_568.json)
# cube: 4/4
# cubeThinCylinderStack: 4/4
# cubeTriPrismStack_house: 1/4
# cylinder: 3/4
# flatRectangle: 4/4
# LBoxTriRoof: 3/4
# LBox_vertical: 0/4
# oval_concertHall: 2/4
# pyramid: 4/4
# rectangleTriPrismOnSide: 3/4
# rectangle_horizontal: 1/4
# rectangle_vertical: 4/4
# tallRectanglePyramidStack: 3/4
# tripleRectangleStackNarrowing: 2/4
# triPrism_horizontal: 4/4
# triPrism_vertical: 0/4
# Completed Validation. Overall Score: 0.65625 (42/64)

# %%
# Compare to all .json drawings in sample_data, 
#  - allows multiple representations of each drawing and takes the average score
base_dir = "sample_data"
reference_filepath = "sample_data/concert_sample/concert_sample_default.json"
# reference_filepath = "sample_data/apt_verticalL_sample/apt_verticalL_sample_default3.json"

avg_scores = {} # Dictionary to store average score for each drawing

# Find average of comparisons to each drawing class' examples
for folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder)

    if not os.path.isdir(folder_path):
        continue

    scores = []

    # Get score of each drawing
    for filename in os.listdir(folder_path):
        if not filename.endswith(".json"):
            continue

        drawing_path = os.path.join(folder_path, filename)

        # Skip the reference file itself in case using sample data as example
        if drawing_path == reference_filepath:
            continue

        dist = compare_drawings_filepath(reference_filepath, drawing_path)
        scores.append(dist)

    if scores:
        avg_scores[folder] = sum(scores) / len(scores)
    else:
        avg_scores[folder] = None  # no valid files

# Print results
for folder, avg in avg_scores.items():
    if avg is None:
        print(f"{folder}: (no drawings found)")
    else:
        print(f"{folder}: {avg:.4f}")
# Out:
# apt1_sample: 0.5412
# apt_verticalL_sample: 0.2757
# concert_sample: 0.5281
# house1_sample: 1.0279

# %%
import numpy as np
def compute_distance_matrix_N(points):
    """
    points: (num_points, 3)
    returns: (num_points, num_points) distance matrix
    """
    points = np.asarray(points, dtype=np.float32)
    diff = points[:, np.newaxis, :] - points[np.newaxis, :, :]
    dist_matrix = np.linalg.norm(diff, axis=-1)
    return dist_matrix


def compute_distance_matrix_relative(points):
    """
    points: (num_points, 3)
    returns: (num_points, num_points) distance matrix
    """
    points = np.asarray(points, dtype=np.float32)

    diff = points[:, None, :] - points[None, :, :]
    dist = np.linalg.norm(diff, axis=-1)

    scale = np.max(dist)
    return dist / (scale + 1e-8)


points_ex = [[1, 2, 3], [2, 2, 3], [2, 3, 3], [1, 3, 3]]
dist_matrix = compute_distance_matrix_N(points_ex)
dist_matrix_relative = compute_distance_matrix_relative(points_ex)
print(f"DistMatrix (Absolute):\n{dist_matrix}")
print(f"DistMatrix (Relative):\n{dist_matrix_relative}")
# Out:
# DistMatrix (Absolute):
# [[0.        1.        1.4142135 1.       ]
#  [1.        0.        1.        1.4142135]
#  [1.4142135 1.        0.        1.       ]
#  [1.        1.4142135 1.        0.       ]]
# DistMatrix (Relative):
# [[0.         0.70710677 1.         0.70710677]
#  [0.70710677 0.         0.70710677 1.        ]
#  [1.         0.70710677 0.         0.70710677]
#  [0.70710677 1.         0.70710677 0.        ]]
